# %% [markdown]
# <a href="https://colab.research.google.com/github/Mokshitha1303/HOG-Histogram-of-Oriented-Gradients-/blob/main/HOG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from skimage import data
from skimage.color import rgb2gray

image = data.astronaut()


hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

rects, weights = hog.detectMultiScale(image_bgr, winStride=(8, 8), padding=(8, 8))

for (x, y, w, h) in rects:
 cv2.rectangle(image_bgr, (x, y), (x + w, y + h), (0, 255, 0), 2)
 image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

 plt.figure(figsize=(10, 10))
plt.imshow(image_rgb)
plt.title('HOG Object Detection')

plt.show()
